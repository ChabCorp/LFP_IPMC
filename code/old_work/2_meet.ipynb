# %% [markdown]
# # Oscillation in eeg

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import warnings 
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
time = 1/20_000 # in seconds
unit_time = 's'
start = 1 # in seconds
end = 1.01

# %%
df = pd.read_csv('../../data/EEGArchi13mPFC.txt')
# df = df.iloc[int(start*20_000):int(end*20_000)] 
df['time'] = df.index * time
df.rename(columns={'0': 'µV'}, inplace=True)
plt.plot(df['time'], df['µV'])
plt.xlabel(f'time ({unit_time})')
plt.ylabel('µV')
plt.title('EEG signal on the first 3000 rows')
plt.savefig('figures/1_EEG_brut.png')

# %% [markdown]
# ## 1 Fourier transform

# %%
import scipy as sp 
import scipy.fftpack
import numpy as np

df_f = df.copy()
df_f['amplitude'] = sp.fftpack.fft(df_f['µV'])/len(df_f['µV'])
df_f["freq"] = 1/df_f['time']
plt.plot(df_f['freq'], np.abs(df_f['amplitude']))
plt.xlabel(f'Frequency')
plt.xlim(0, 150)
plt.ylabel('Amplitde')
plt.title('Fourier transform of the EEG signal')
# plt.savefig('figures/2_EEG_fourier.png')
# Out:
# Text(0.5, 1.0, 'Fourier transform of the EEG signal')

# %% [markdown]
# - gamma = 30 Hz
# - Theta = 5-12 Hz

# %%
dd = df_f.copy()
dd = dd[dd['freq'] < 30.01]
dd = dd[dd['freq'] > 29.8]
dd = dd.sort_values(by='freq')
# plt.plot(dd['freq'], np.abs(dd['amplitude']))

# %% [markdown]
# peut être une normalisation a faire

# %% [markdown]
# ## Article

# %% [markdown]
# Fig1A

# %%
htmap = pd.DataFrame()
htmap["freq"] = 1/df_f["time"]
htmap = htmap[htmap["freq"] < 150]
# change the calculation of the BLP_freq and power
htmap["BLP_freq"] = np.abs(htmap["freq"])
htmap["power"] = htmap["BLP_freq"]**2
sns.scatterplot(data = htmap, x = "freq", y = "BLP_freq",hue="power", palette="viridis", legend=False)
plt.xlim(0,150)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
htmap = htmap.set_index(['freq'])
htmap.drop(columns=['power'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Tom\Documents\Cours\Polytech\5A\S1\Biol_Integrative\LFP_IPMC\code\2_meet.ipynb Cellule 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/Documents/Cours/Polytech/5A/S1/Biol_Integrative/LFP_IPMC/code/2_meet.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> htmap = htmap.set_index(['freq'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Tom/Documents/Cours/Polytech/5A/S1/Biol_Integrative/LFP_IPMC/code/2_meet.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> htmap.drop(columns=['power'], inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Tom/Documents/Cours/Polytech/5A/S1/Biol_Integrative/LFP_IPMC/code/2_meet.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> htmap
#
# File c:\Users\Tom\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Tom\anaconda3\lib\site-packages\pandas\core\frame.py:5503, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5500                 missing.append(col)
#    5502 if missing:
# -> 5503     raise KeyError(f"None of {missing} are in the columns")
#    5505 if inplace:
#    5506     frame = self
#
# KeyError: "None of ['freq'] are in the columns"

# %% [markdown]
# sns.heat

# %% [markdown]
# ## Create heatmap
# sur l'intervalle bio possible

# %%
range_min = 0
range_max = 150
df_f["freq"] = 1/df_f["time"]
df_f = df_f[(df_f["freq"] > range_min) & (df_f["freq"] < range_max)]
df_f
# Out:
#          µV      time           amplitude        freq
# 134       1   0.00670 -0.001105-0.002105j  149.253731
# 135       1   0.00675 -0.001030+0.000486j  148.148148
# 136       0   0.00680 -0.004670+0.000379j  147.058824
# 137      -3   0.00685 -0.002098+0.000958j  145.985401
# 138      -1   0.00690  0.002699+0.003603j  144.927536
# ...      ..       ...                 ...         ...
# 1739494   0  86.97470 -0.003865+0.003142j    0.011498
# 1739495   0  86.97475  0.003693-0.001373j    0.011498
# 1739496   0  86.97480  0.004371-0.001578j    0.011498
# 1739497   0  86.97485 -0.002863-0.002170j    0.011498
# 1739498   0  86.97490  0.002112+0.000650j    0.011498
#
# [1739365 rows x 4 columns]

# %%
# htmap = df_f.copy()
# htmap = htmap.drop(columns=['µV'])
# sns.heatmap(htmap, annot=True)
